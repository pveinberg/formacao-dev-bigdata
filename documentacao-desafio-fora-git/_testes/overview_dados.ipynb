# %%
import pandas as pd
import os
from datetime import timedelta
from configparser import ConfigParser

# %%
config = ConfigParser()
config.read('./../desafio/scripts/config.ini')
diretorio_arquivos = os.path.expanduser(f"{config['GERAL']['BASE_DIR']}{config['EDGE']['EDGE_BASE_DIR']}") 
destino_hqls = os.path.expanduser(f"{config['GERAL']['BASE_DIR']}{config['GERAL']['HQL_DIR']}")

# %%
files = os.listdir(diretorio_arquivos)
files
# Out:
# ['CLIENTES.csv', 'ENDERECO.csv', 'DIVISAO.csv', 'VENDAS.csv', 'REGIAO.csv']

# %%
metadados = []
for file in files:
    data = pd.read_csv(f"{diretorio_arquivos}/{file}", sep=';')
    campos_tabela = [f"{column.lower().replace(' ', '_')} string" for column in list(data.columns)]
    campos_tabela.insert(0, f"id_{file.split('.')[0].lower()} string")
    metadados.append(
        {'tabela': file.split('.')[0].lower(), 
         'campos': campos_tabela})

metadados[:1]
# Out:
# [{'tabela': 'clientes',
#   'campos': ['id_clientes string',
#    'address_number string',
#    'business_family string',
#    'business_unit string',
#    'customer string',
#    'customerkey string',
#    'customer_type string',
#    'division string',
#    'line_of_business string',
#    'phone string',
#    'region_code string',
#    'regional_sales_mgr string',
#    'search_type string']}]

# %%
# set dll

DB_EXT=config['HIVE']['DB_EXT'].lower()
DB_STG=config['HIVE']['DB_STG'].lower()
HDFS_BASE_DIR=config['HDFS']['HDFS_BASE_DIR']
PARTICAO=(datetime.today() - timedelta(1)).strftime('%Y%m%d')

for tbl in metadados:
    campos = ",\n\t".join(tbl['campos'])
    create=f"""-- TABELA {tbl['tabela']} on Hive

    CREATE DATABASE IF NOT EXISTS {DB_EXT}; 
    CREATE DATABASE IF NOT EXISTS {DB_STG};

    DROP TABLE {DB_EXT}.tbl_{tbl['tabela']};

    CREATE EXTERNAL TABLE IF NOT EXISTS {DB_EXT}.tbl_{tbl['tabela']} (
        {campos}
    )
    COMMENT "Tabela de {tbl['tabela']}"
    ROW FORMAT DELIMITED
    FIELDS TERMINATED BY "|"
    STORED AS TEXTFILE
    location  "{HDFS_BASE_DIR}/raw"
    TBLPROPERTIES ("skip.header.line.count"="1");

    SELECT count(*) as _records FROM {DB_EXT}.tbl_{tbl['tabela']} LIMIT 10;

    -- Tabela {tbl['tabela']} particionada

    DROP TABLE {DB_STG}.tbl_{tbl['tabela']};

    CREATE TABLE IF NOT EXISTS {DB_STG}.tbl_{tbl['tabela']} (
        {campos}
    )
    PARTITIONED BY (DT_FOTO STRING)
    ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.orc.OrcSerde'
    STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.orc.OrcInputFormat'
    OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.orc.OrcOutputFormat'
    TBLPROPERTIES ('orc.compress'='SNAPPY');

    SET hive.exec.dynamic.partition=true;
    SET hive.exec.dynamic.partition.mode=nonstrict;

    INSERT OVERWRITE TABLE 
        {DB_STG}.tbl_{tbl['tabela']}
    PARTITION(DT_FOTO)
    SELECT
        {campos},
        '{PARTICAO}' as DT_FOTO
    FROM {DB_EXT}.tbl_{tbl['tabela']};

    SELECT count(*) as _records FROM {DB_STG}.tbl_{tbl['tabela']} LIMIT 10;

    -- --------------------------------------------------------------
    --  FIM DO SCRIPT {tbl['tabela']}
    -- --------------------------------------------------------------

    """
    destino = f"{destino_hqls}/create_table_{tbl['tabela']}.hql"
    
    file_hql = open(destino, 'w')
    file_hql.write(create)
    file_hql.close()

# %%
# endereco
endereco = pd.read_csv('./../raw/ENDERECO.csv', sep=';')
endereco.shape
# Out:
# (455, 9)

# %%
endereco.head()
# Out:
#    Address Number                       City Country  \
# 0        10000000                      Akron      US
# 1        10000453                                 UK
# 2        10000455           Huntington Beach      US
# 3        10000456                   Edmonton      CA
# 4        10000458                    Saginaw      US
#
#                          Customer Address 1  \
# 0                               PO Box 6258
# 1
# 2                         7392 Count Circle
# 3                          8151 Wagner Road
# 4                                PO Box 840
#
#                          Customer Address 2  \
# 0
# 1
# 2
# 3
# 4
#
#                          Customer Address 3  \
# 0
# 1
# 2
# 3
# 4
#
#                          Customer Address 4 State      Zip Code
# 0                                              OH         44312
# 1                                             NaN
# 2                                              CA         92647
# 3                                              AB       T6E 4N6
# 4                                              MI         48606

# %%
# endereco.City.unique()
[row2 for row2 in [row.strip() for row in list(endereco['Customer Address 1'].unique())] if row2 != '']
# Out:
# ['PO Box 6258',
#  '7392 Count Circle',
#  '8151 Wagner Road',
#  'PO Box 840',
#  '709 Rivergate Parkway',
#  '1391 Gay Lussac',
#  '6311 North Lindbergh Boulevard',
#  '3213 Orange Grove Avenue',
#  'Attention:  Accounts Payable',
#  'Al Thalia Street',
#  '8000 Haskell Avenue',
#  '3290 Monier Circle #100',
#  'PO Box 3265',
#  '5745 N Tryon Street',
#  '8120 E Doyle Springs Road',
#  'Attention: Accounts Payable',
#  'Box 5516',
#  '1550 Aereli Avenue',
#  '1594 Nicholson Street',
#  '50 Mystic Avenue',
#  'Spicer Clark - Hurth Off Highway Div',
#  'PO Box 266',
#  'Attention: Doris Nielson',
#  'Kadaka Road 72 a',
#  'PO Box 99',
#  '1200 North Ellis Street',
#  '4760 NW 165th Street',
#  '7223 Girard Road',
#  '12000 Balls Ford Road',
#  '2755 Kirila Boulevard',
#  'PO Box 2484',
#  '4747 N Channel Ave',
#  '3F Shinwoo Building',
#  'PO Box 20505',
#  '9555 Airline Highway',
#  'Vehicle Operations',
#  '601 East Gowen Road',
#  'Paseo Colon Calles 34-36',
#  '7225 NW 25th Street',
#  'PO Box 5364',
#  '1801 NW 82nd Ave',
#  'AV 6 DE DICIEMBRE',
#  '1023 Kansas Avenue',
#  '1101A Potomac Avenue',
#  '4410 Highway 80 East',
#  '8F No.19 Chang Chun Road',
#  'DBA Pronto Jobbers Warehouse',
#  '5711 West 36th Street',
#  '22015 South I-35',
#  'PO Box 194255',
#  'Limited Reg Number 28388',
#  '3601 Amarillo Boulevard East',
#  '1287 US Highway 59 North',
#  '2106 South Riverside Road',
#  '2621 State Route 57',
#  'Hiekkakiventie 7',
#  'Rua Sepetiba 464',
#  '23308 Airpark Drive',
#  '10023 128th St. E #7',
#  'PO Box 578',
#  '209 Sanford Road (Route 109)',
#  '301 Iddings Street',
#  '508 South First Street',
#  'DBA Badlands Off Road Park',
#  'Global Motorsport Parts Inc',
#  'PO Box 105',
#  '2125 Whitney Avenue',
#  '1477 Davril Circle',
#  'Industriestrasse 17',
#  '812 Draper Avenue',
#  '4103 Holiday Drive',
#  '3248 Auburn Boulevard',
#  'Plaza Venezuela 1413-1425',
#  '550 Du Parc Boulevard',
#  '3355 American Drive',
#  '904 Billy Mitchell Boulevard',
#  'PO Box 450',
#  '12 Lexington Street',
#  'PO box 204658',
#  '610 Garfield Avenue',
#  '167 East Kalamazoo Avenue',
#  '2400 Highway 19N',
#  '4455 Dardanelle Drive',
#  'PO Box 065',
#  'PO Box 7100',
#  'PO Box 2143',
#  'PO Drawer 40',
#  '17010 S Main Street',
#  '208 W Main',
#  '170 Industrial Boulevard',
#  '522 Montana Avenue',
#  '9605 56th Avenue',
#  'PO Box 588',
#  '3513 West Highway 13',
#  '5702 Industry Lane Unit B1 & 2',
#  'PO Box 849',
#  'Attention  Accounts Payable Department',
#  '231 Yangjae Dong',
#  '877 1st Avenue NW',
#  '317 North Main Street',
#  '1477 E Highway 356',
#  '13296 County Highway 00',
#  '703 Waverly Street',
#  '1942 W 11th Avenue',
#  '901 Oak Ridge Turnpike',
#  '32722 Highway 45',
#  '300 Ingersoll Street',
#  'PO Box 19858 Station N',
#  'PO Box 8808',
#  'Rua Eng Ferreira Dia 241-243',
#  'PO Box 2640',
#  '2177 Dale Avenue SE',
#  'Worldwide Purchasing',
#  'PO Box 4658',
#  'PO Box 1005',
#  'PO Box 510',
#  'RR1 Box 9',
#  '44 Tunkhannock Avenue',
#  'Av 6A Norte 25 N 43',
#  'Vagnhofda 23',
#  'PO Box 36409',
#  'PO Box 250825',
#  'PO Box 5222',
#  'Dallas PDC #15',
#  '2015 San Juan Boulevard',
#  '3343 Shelby Street',
#  '207 North Scott',
#  '5821 Hampton Avenue',
#  'Rinconada De La Floresta 1137',
#  '1510 Merced Street',
#  'S Gravendam Seweg 53',
#  '1935 S Campbell',
#  'Accounting Department Service & Parts',
#  '2916-21st Street Northeast',
#  '12900 SE Capps Road',
#  'Chicago PDC #22',
#  "Avda Bdo O'Higgins",
#  'Division of Western Truck Sales Inc',
#  'Division of Parkhurst',
#  'PO Box 206',
#  '3056 Eastern Avenue SE',
#  'Attention: Ann Borden',
#  'Attention: Accounts Payable Department',
#  'Svarvarvagen 14',
#  '2192 Viking Drive',
#  '5750 Ringe',
#  '1601 East 29th Street',
#  'Attention: Anna Markert',
#  'PO Box 14311',
#  'PO Box 7005',
#  '1051 West 7th Street',
#  '975 Main Street',
#  '60 Depot Street',
#  'Attention Accounts Payable Department',
#  'Greenville PDC #23',
#  '4700 Rangeline Road',
#  'PO Box 6307',
#  'PO Box 2338',
#  '6025 Corridor Parkway',
#  'Unicity Distribution Systems',
#  'PO Box 129',
#  '6590 SW Fallbrook Place',
#  '580 Yankee Doodle Rd Ste 1200',
#  '7640 North Telegraph',
#  '4200 S Morgan Street',
#  'Transversal 49 No. 102-00',
#  '10401 Boul Parkway',
#  '8901 Montana Avenue',
#  'PO Box 660',
#  'PO Box 10455',
#  '11811 West Silver Spring Drive',
#  'Advance Auto Parts',
#  'PO Box 762',
#  'Rue Champion',
#  'Box 1178',
#  'EDIF N 4141',
#  'Solec 44',
#  'PO Box 790',
#  'PO Box 12932',
#  '17 Perry Road',
#  '12805 SW 77th Place',
#  '1028 Saunders Lane',
#  '2400 R E O Drive',
#  'PO Box 871 Safat',
#  'Field Accounting Department',
#  'Dagher Plast Building 17',
#  '128 So. 2nd Avenue',
#  '18 North East 7th Avenue',
#  '6029 Mechanicsville Pike',
#  'Sacramento PDC #13',
#  'Jacksonville PDC #21',
#  '1101 N College Avenue',
#  '861 West US Highway 30',
#  '6710 76 Avenue',
#  'PO Box 880 PC-112',
#  '2445 FM 2920',
#  'PO BOX 8808',
#  '7940 New Jersey Avenue',
#  'PO Box 409',
#  '3564 Buford Highway',
#  'New York PDC #20',
#  '7210 Gateway East',
#  '500 Airport Drive',
#  '10901 Macleod Trail South',
#  '299 East Country Road 300 South',
#  '1537 Sabraton Ave',
#  'Am Schwimmbad 8',
#  'Corporation USA',
#  '7216 Ritchie Highway',
#  '16241 South Us 27',
#  '2649 East Mulberry Street',
#  'PO Box 447',
#  'PO Box 80',
#  '1155 Mackay Street',
#  'Attention: Rodrigo Yrarrazaval',
#  'PO Box 3445',
#  'Attention: Mr. Bob Smeigh',
#  'Kelapa Gading Kirana',
#  '540 South Rock Boulevard',
#  'Brobekkveien 105',
#  '5415 Lamco Drive',
#  'Avda 10 De Mayo S/N',
#  'PO Box 547',
#  '2600 West Route 120',
#  'One Cabela Drive',
#  'PO Box 549',
#  '7320 West Market Street',
#  'PO Box 3382',
#  '1127 South First Street NE',
#  '#9 - 19257 Enterprise Way',
#  'PO Box 5418',
#  '316 Millar Avenue',
#  '14312 Stenbock Way NE #F',
#  '7440 South West Bonita Road',
#  'Los Angeles PDC #14',
#  '480 Gordon Baker Road',
#  '14296 South Pony Express Road',
#  'Michigan Truck Plant',
#  'PO Box 460',
#  '13101 SE 84th ave',
#  '100 Gasoline Alley  Suite A',
#  '10930 West 44th Avenue',
#  '3251 East Imperial Highway',
#  '1817 East Yellowstone',
#  'Memphis PDC #19',
#  '815 Hellam Street',
#  '9475 192 Street',
#  'FOB: Clackamas',
#  '13208 East 40 Highway',
#  '2700 Northern Drive South East',
#  '1-2-4 Takamatsu',
#  'Cnr Avalon Drv & Tasman Road',
#  'PO Box 2187',
#  '7779 Dixie Highway',
#  '99 Calais Road',
#  'S&PD-Special Accounts Sales',
#  '8 N Industrial Park Road',
#  'PO Box 10361',
#  'PO Box 113',
#  '1760 C Airport Road',
#  'Av Blandin Chacao',
#  '1665 Shawson Drive',
#  '201 Old Boiling Springs Road',
#  '13907 S Kostner Avenue',
#  '12110 Best Place',
#  '845 Third Street',
#  'PO Box 958',
#  'Detroit Technical Center',
#  '3340 A Sunrise Boulevard',
#  'Attention: Linda',
#  'PO Box 24217',
#  '5325 Still Creek Road',
#  '1723 Webb Drive',
#  '21533 Mound Road',
#  'PO Box 900',
#  'Landstrasse 18',
#  '8300 Lane Drive',
#  'PO Box 86222',
#  '2610 NW 10th Street',
#  '400 Jay Street',
#  '18412 96 Avenue',
#  '600 South Brooks Avenue',
#  "c/o Tom's Bronco Parts",
#  '7600 South Santa Fe',
#  '7700 Counts Massie Road',
#  'PO Box 899',
#  'PO Box 30659',
#  '915 West 42nd',
#  '513 West Waters Avenue',
#  '15625 Highway North East',
#  'Bellsingel 2 1119NV',
#  '640 N Eldorado Street',
#  '2900 Northwest 73rd Street',
#  'PO Box 1006',
#  'DUMEN SOK. No:3 D.9',
#  'Central Division',
#  '106 B David Green Road',
#  '60 Lafayette Road',
#  'PO Box 70',
#  'Av Eusebio Ayala 3321',
#  'PO Box 7647',
#  'Defense Const. Supply Center',
#  'PO Box 249',
#  'PO Box 57',
#  'PO Box 582510',
#  '1-16-33 Kotsubo Zushi',
#  '9950 Jeronimo Road',
#  '16215 118th Avenue',
#  '580 Waterman Avenue',
#  '9440 North Whitaker Road',
#  'Division Of Pontiac Michigan',
#  'PO Box 13056',
#  '124 Hegenberger Loop',
#  'PO Box 1010',
#  'Modulo 2 Manzana 27',
#  'Cache Border Services',
#  '8302 Jet Pilot',
#  'PO Box 511',
#  'Americas Body Company',
#  'PO Box 2017',
#  'PO Box 174',
#  '907 Cole Street',
#  'RR 2 BOX 9',
#  '1151 W Main',
#  'Bromley St Lye Stourbridge',
#  '815 Circle Drive East',
#  '2402 West Valley Highway North',
#  'c/o Rampar International Trade Corp.',
#  '226 North 13th',
#  '395 Smitty Way',
#  '1920 East Front Street',
#  '725 North Twin Oaks Valley Road',
#  'PO Box 568',
#  '9049 Tyler Blvd.',
#  '6127 San Pedro Avenue',
#  '13270 SE Pheasant Court',
#  '1301 East 64th Avenue',
#  '150-3 Chilkei-Dong',
#  'PO Box 80509',
#  '731 North Beford Road',
#  'Private Mail Bag 53',
#  'Central Accounting Service',
#  '4567 Federal Boulevard',
#  'RU-3 Hamamatsu Nishi',
#  'Parts Division',
#  'PO Box 5308',
#  '515 Oak Point Highway',
#  '390 Fountain Street',
#  '730 North Central',
#  '7221 Highway 64',
#  '8503 Hilltop Drive',
#  'A Scott Fetzer Company',
#  'PO Box 4405',
#  '3545 South Richey Boulevard',
#  '19745 Meekland Avenue',
#  '2401 East 31st Street',
#  'PO Box 366',
#  'Kirchstrasse 39',
#  '3631 South Bagley Avenue',
#  '217 West 3rd Street',
#  '666  South Thompson Road',
#  '1111 Finch Avenue West',
#  '6260 - Place Northcrest Suite 305',
#  'Attention: Paul Grady',
#  '4345 South West Boulevard',
#  '4260 North Nevada Avenue',
#  'PO Box 100603',
#  '1809 Main Street',
#  '3100 Mt. View Drive',
#  '3650 Bay Street',
#  'PO Box 21',
#  'Order Processing Group',
#  '6104 Young Road',
#  '125 Hampton Ct.',
#  'PO Box 3283',
#  'PO Box 640',
#  'One Industrial Complex',
#  'PO OB 20141',
#  '4532 Enterprise Drive',
#  '850 Commerce Street',
#  'Southern Maryland 4 X 4 Inc',
#  '1143 W 2nd Street',
#  'PO Box 667',
#  '3519 Arsonal Way',
#  '5300 Glenmont Drive',
#  '801 West Artesia Boulevard',
#  '308 53 Avenue SE',
#  '2 Calle 25-80 Zona - 15 Vista',
#  '5100 Highway 93 South',
#  '2301 Central Parkway',
#  'PO Box 461090',
#  'Weser Ems Strasse 2-4',
#  'Unit 403 - 17665 - 66A Avenue',
#  '1880 N Westwood',
#  '334 North Hall Street',
#  'PO Box 26',
#  'PO Box 220',
#  '1275 North 6 Mile Road',
#  '97 Banawe Street',
#  '4353 W 1900 N-48',
#  '500 Highway 18 West',
#  '3241 South Lower Tug Fork Road',
#  'PO Box 22249',
#  '1201 Sycamore Avenue',
#  '100 East Inyo',
#  '2280 South State Street',
#  'Aut Reg Del Centro Valencia',
#  '3204 W Mill Road',
#  'PO Box 68',
#  '9111 41 Avenue',
#  '63 Bridge Street',
#  '6501 Adamo Drive',
#  '910 North East 4th Street',
#  'General Pardinas 112 Bis',
#  '2649 R W Johnson Boulevard',
#  '3356 Kermit Highway',
#  '2210 Bowen Road',
#  '10400 Plano Road',
#  'Attention: Charlene Hoyer']

# %%
import re

def clean_empty(_txt):
    rs = re.search("\s{2,}", _txt)
    if isinstance(rs, re.Match):
        print(rs.group())
        if rs.span()[0] == 0:
            return "Não informado"
        _txt = _txt.replace(rs.group(), ' ')

    return _txt

assert clean_empty("   ") == "Não informado"
assert clean_empty("Luiza") == "Luiza"
assert clean_empty("Luiza Batista") == "Luiza Batista"
assert clean_empty("Luiza  Batista") == "Luiza Batista"
# assert clean_empty("Luiza Batista  ") == "Luiza Batista"

# %%
{'actual_delivery_date': 'datetime64[ns]',
 'customerkey': 'object',
 'datekey': 'datetime64[ns]',
 'discount_amount': 'float',
 'invoice_date': 'datetime64[ns]',
 'invoice_number': 'object',
 'item_class': 'object',
 'item_number': 'object',
 'item': 'object',
 'line_number': 'object',
 'list_price': 'float',
 'order_number': 'object',
 'promised_delivery_date': 'datetime64[ns]',
 'sales_amount': 'float',
 'sales_amount_based_on_list_price': 'float',
 'sales_cost_amount': 'float',
 'sales_margin_amount': 'float',
 'sales_price': 'float',
 'sales_quantity': 'float',
 'sales_rep': 'float',
 'u_m': 'object',
 'dt_foto': 'datetime64[ns]'}

# %%
import math
math.trunc(0) == 0
# Out:
# True

# %%
e = endereco.City.map(clean_empty)
e[:10]
# Out:
# 0               Akron
# 1       Não informado
# 2    Huntington Beach
# 3            Edmonton
# 4             Saginaw
# 5      Goodlettsville
# 6        Boucherville
# 7           Hazelwood
# 8     North Highlands
# 9            Montreal
# Name: City, dtype: object
